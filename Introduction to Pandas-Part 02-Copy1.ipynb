# %% [markdown]
# # <center> Introduction to Pandas : Part 2

# %% [markdown]
# #### Loading the dependencies

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Loading the dataset

# %%
data = pd.read_csv('./titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### droping the columns

# %%
data.drop(columns=['PassengerId', 'Cabin', 'Ticket', 'Name'], inplace=True)

# %%
data.head(10)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S
# 5         0       3    male   NaN      0      0   8.4583        Q
# 6         0       1    male  54.0      0      0  51.8625        S
# 7         0       3    male   2.0      3      1  21.0750        S
# 8         1       3  female  27.0      0      2  11.1333        S
# 9         1       2  female  14.0      1      0  30.0708        C

# %% [markdown]
# #### groupby

# %% [markdown]
# #### Gender wise average age

# %%
data.groupby(['Sex'])['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
data.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
data.groupby(['Embarked'])['Age'].mean()
# Out:
# Embarked
# C    30.814769
# Q    28.089286
# S    29.445397
# Name: Age, dtype: float64

# %%
data.groupby(['Embarked'])['Age'].max()
# Out:
# Embarked
# C    71.0
# Q    70.5
# S    80.0
# Name: Age, dtype: float64

# %%
Sex_Survived_Average = data.groupby(['Sex'])['Survived'].sum()

# %%
Sex_Survived_Sum
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
Sex_Survived_Average = data.groupby(['Sex'])['Survived'].mean()*100

# %%
Sex_Survived_Average
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %% [markdown]
# #### Querying the data

# %%
data[data['Sex'] == 'male']
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 5           0       3  male   NaN      0      0   8.4583        Q
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
# 889         1       1  male  26.0      0      0  30.0000        C
# 890         0       3  male  32.0      0      0   7.7500        Q
#
# [577 rows x 8 columns]

# %%
data.query("Sex == 'male'")
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 5           0       3  male   NaN      0      0   8.4583        Q
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
# 889         1       1  male  26.0      0      0  30.0000        C
# 890         0       3  male  32.0      0      0   7.7500        Q
#
# [577 rows x 8 columns]

# %%
data.query("Sex == 'male' & Embarked == 'S' & Pclass == 3")
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 7           0       3  male   2.0      3      1  21.0750        S
# 12          0       3  male  20.0      0      0   8.0500        S
# 13          0       3  male  39.0      1      5  31.2750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 876         0       3  male  20.0      0      0   9.8458        S
# 877         0       3  male  19.0      0      0   7.8958        S
# 878         0       3  male   NaN      0      0   7.8958        S
# 881         0       3  male  33.0      0      0   7.8958        S
# 884         0       3  male  25.0      0      0   7.0500        S
#
# [265 rows x 8 columns]

# %%
data.query("Sex == 'male' & Embarked == 'S'")
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# 12          0       3  male  20.0      0      0   8.0500        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 878         0       3  male   NaN      0      0   7.8958        S
# 881         0       3  male  33.0      0      0   7.8958        S
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
#
# [441 rows x 8 columns]

# %%
Sex_male_01 = data.query("Sex == 'male'")
Sex_male_01
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3  male  22.0      1      0   7.2500        S
# 4           0       3  male  35.0      0      0   8.0500        S
# 5           0       3  male   NaN      0      0   8.4583        Q
# 6           0       1  male  54.0      0      0  51.8625        S
# 7           0       3  male   2.0      3      1  21.0750        S
# ..        ...     ...   ...   ...    ...    ...      ...      ...
# 883         0       2  male  28.0      0      0  10.5000        S
# 884         0       3  male  25.0      0      0   7.0500        S
# 886         0       2  male  27.0      0      0  13.0000        S
# 889         1       1  male  26.0      0      0  30.0000        C
# 890         0       3  male  32.0      0      0   7.7500        Q
#
# [577 rows x 8 columns]

# %%
Sex_Female = data.query("Sex != 'male'")
Sex_Female
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 8           1       3  female  27.0      0      2  11.1333        S
# 9           1       2  female  14.0      1      0  30.0708        C
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 880         1       2  female  25.0      0      1  26.0000        S
# 882         0       3  female  22.0      0      0  10.5167        S
# 885         0       3  female  39.0      0      5  29.1250        Q
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
#
# [314 rows x 8 columns]

# %%
Fare_under10 = data.query("Fare < 10 & Age >= 10")
Fare_under10
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch    Fare Embarked
# 0           0       3    male  22.0      1      0  7.2500        S
# 2           1       3  female  26.0      0      0  7.9250        S
# 4           0       3    male  35.0      0      0  8.0500        S
# 12          0       3    male  20.0      0      0  8.0500        S
# 14          0       3  female  14.0      0      0  7.8542        S
# ..        ...     ...     ...   ...    ...    ...     ...      ...
# 876         0       3    male  20.0      0      0  9.8458        S
# 877         0       3    male  19.0      0      0  7.8958        S
# 881         0       3    male  33.0      0      0  7.8958        S
# 884         0       3    male  25.0      0      0  7.0500        S
# 890         0       3    male  32.0      0      0  7.7500        Q
#
# [235 rows x 8 columns]

# %%
Sex_Age_20 = data.query("Sex == 'male' & Age == 22.0")

# %%
Sex_Age_20
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3  male  22.0      1      0    7.2500        S
# 60          0       3  male  22.0      0      0    7.2292        C
# 80          0       3  male  22.0      0      0    9.0000        S
# 112         0       3  male  22.0      0      0    8.0500        S
# 212         0       3  male  22.0      0      0    7.2500        S
# 225         0       3  male  22.0      0      0    9.3500        S
# 243         0       3  male  22.0      0      0    7.1250        S
# 287         0       3  male  22.0      0      0    7.8958        S
# 320         0       3  male  22.0      0      0    7.2500        S
# 373         0       1  male  22.0      0      0  135.6333        C
# 395         0       3  male  22.0      0      0    7.7958        S
# 478         0       3  male  22.0      0      0    7.5208        S
# 521         0       3  male  22.0      0      0    7.8958        S
# 553         1       3  male  22.0      0      0    7.2250        C
# 588         0       3  male  22.0      0      0    8.0500        S

# %%
Sex_Age_20_SibSp_1 = data.query("Sex == 'male' & Age == 22.0 & SibSp == 1")
Sex_Age_20_SibSp_1
# Out:
#    Survived  Pclass   Sex   Age  SibSp  Parch  Fare Embarked
# 0         0       3  male  22.0      1      0  7.25        S

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Class 12

# %% [markdown]
# ### Pivot()

# %%
data.pivot_table(values='Fare', index='Sex', columns='Pclass', aggfunc='sum')
# Out:
# Pclass          1          2          3
# Sex
# female  9975.8250  1669.7292  2321.1086
# male    8201.5875  2132.1125  4393.5865

# %%
pivot_02 = data.pivot_table(values='Fare', index='Embarked', columns='Pclass', aggfunc='sum')

# %%
pivot_02
# Out:
# Pclass            1          2          3
# Embarked
# C         8901.0750   431.0917   740.1295
# Q          180.0000    37.0500   805.2043
# S         8936.3375  3333.7000  5169.3613

# %%
pivot_03 = data.pivot_table(values='Fare', index='Embarked', columns='Pclass', aggfunc='mean')

# %%
pivot_03
# Out:
# Pclass             1          2          3
# Embarked
# C         104.718529  25.358335  11.214083
# Q          90.000000  12.350000  11.183393
# S          70.364862  20.327439  14.644083

# %%
data.select_dtypes('int64')
# Out:
#      Survived  Pclass  SibSp  Parch
# 0           0       3      1      0
# 1           1       1      1      0
# 2           1       3      0      0
# 3           1       1      1      0
# 4           0       3      0      0
# ..        ...     ...    ...    ...
# 886         0       2      0      0
# 887         1       1      0      0
# 888         0       3      1      2
# 889         1       1      0      0
# 890         0       3      0      0
#
# [891 rows x 4 columns]

# %%
data.select_dtypes(float)
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data.select_dtypes(object)
# Out:
#         Sex Embarked
# 0      male        S
# 1    female        C
# 2    female        S
# 3    female        S
# 4      male        S
# ..      ...      ...
# 886    male        S
# 887  female        S
# 888  female        S
# 889    male        C
# 890    male        Q
#
# [891 rows x 2 columns]

# %% [markdown]
# ### insert

# %% [markdown]
# #### This will insert a new column in the desired place. For this purpose let's create a new column first using np.random

# %%
len(data)
# Out:
# 891

# %%
np.random.randint(0, 100, size = 891)
# Out:
# array([16,  5, 46, 68,  3, 60, 10, 36, 68, 61,  8, 37, 97, 48, 65, 38, 11,
#         7,  8, 99, 22, 86, 32, 32, 45, 72, 38, 56,  0, 40, 93, 82, 49, 22,
#        32, 52, 67, 46, 33, 32, 97, 18, 54, 38, 46,  0,  7, 60,  2, 15,  5,
#        80, 34, 95, 76, 27, 34, 32, 11, 59, 57, 33, 75, 51, 91, 53, 19, 21,
#        89, 22, 83, 16, 53,  7, 77, 22, 82, 95, 74, 86, 45,  4, 41, 81, 81,
#        84, 59,  0, 58, 30, 95, 76,  4, 67, 97, 94,  4, 15, 10, 19, 51, 34,
#        30, 50, 68, 16, 65, 33, 74, 20, 78,  8, 13,  2, 73, 61, 49, 60, 47,
#        99, 54, 36, 51,  9,  7, 37, 22, 34,  5, 70, 20, 12, 92, 30, 65, 25,
#        82, 63, 13, 67, 34,  4, 32, 38, 47, 23, 94,  4, 16, 69, 96, 10, 84,
#        92, 12, 99, 57, 97, 39, 83, 46, 48, 75, 98, 79, 53, 57, 78, 19, 15,
#         5,  4, 76, 74, 85, 53, 25, 16, 76, 55, 34, 15, 73, 91, 15, 59, 78,
#        98,  3, 68,  2,  9, 39, 43, 78, 45, 65, 19, 50, 99, 32, 33, 52,  2,
#         0, 49, 88, 73,  3, 96, 94, 32, 27, 21, 11, 94,  5, 77, 52, 23, 29,
#        63, 33, 64, 34, 64, 33, 30,  2, 57, 23, 13, 50, 16, 71, 43, 79, 78,
#        68, 49, 23, 53, 63, 23, 56, 13, 57, 91, 51, 13, 93, 43, 66, 18, 62,
#        40, 96, 87, 99, 75, 33, 12, 40, 92,  8,  9, 81, 10, 55, 31, 53, 64,
#        16, 16, 27, 29, 47, 17, 39, 12, 37, 97, 57,  1, 92, 70, 79, 50, 73,
#        24, 73, 57,  5, 36, 31,  0, 35, 13, 98, 72, 43, 24,  0, 33,  2, 16,
#         7, 34, 48, 21, 35, 91, 77, 27, 23, 60, 91, 65, 91, 76,  6, 14, 29,
#        28, 31, 42, 82, 38, 77, 56, 15, 24, 36, 34,  1, 46, 10, 36, 85, 79,
#        58, 90, 70, 95, 19, 71, 20, 79, 19,  8, 97, 57, 44,  8, 72,  3, 18,
#        65, 57,  4, 29, 51, 89, 53])

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.insert(4, 'NewColumn', column)

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  NewColumn  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0         85      1      0   7.2500        S
# 1         1       1  female  38.0         69      1      0  71.2833        C
# 2         1       3  female  26.0         59      0      0   7.9250        S
# 3         1       1  female  35.0         13      1      0  53.1000        S
# 4         0       3    male  35.0         55      0      0   8.0500        S

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'NewColumn', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
data.drop(columns=['NewColumn'], inplace=True)

# %% [markdown]
# ### cumsum()

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data[['Fare', 'Age']].cumsum()
# Out:
#            Fare       Age
# 0        7.2500     22.00
# 1       78.5333     60.00
# 2       86.4583     86.00
# 3      139.5583    121.00
# 4      147.6083    156.00
# ..          ...       ...
# 886  28602.7493  21128.17
# 887  28632.7493  21147.17
# 888  28656.1993       NaN
# 889  28686.1993  21173.17
# 890  28693.9493  21205.17
#
# [891 rows x 2 columns]

# %% [markdown]
# ### replace

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Sex.replace({'male':0, 'female':1}, inplace=True)
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    0  22.0      1      0   7.2500        S
# 1           1       1    1  38.0      1      0  71.2833        C
# 2           1       3    1  26.0      0      0   7.9250        S
# 3           1       1    1  35.0      1      0  53.1000        S
# 4           0       3    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    0  27.0      0      0  13.0000        S
# 887         1       1    1  19.0      0      0  30.0000        S
# 888         0       3    1   NaN      1      2  23.4500        S
# 889         1       1    0  26.0      0      0  30.0000        C
# 890         0       3    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Pclass.replace({3:'Third', 2:'Second', 1:'First'}, inplace=True)
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0   Third    0  22.0      1      0   7.2500        S
# 1           1   First    1  38.0      1      0  71.2833        C
# 2           1   Third    1  26.0      0      0   7.9250        S
# 3           1   First    1  35.0      1      0  53.1000        S
# 4           0   Third    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0  Second    0  27.0      0      0  13.0000        S
# 887         1   First    1  19.0      0      0  30.0000        S
# 888         0   Third    1   NaN      1      2  23.4500        S
# 889         1   First    0  26.0      0      0  30.0000        C
# 890         0   Third    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# ### rename

# %%
data.rename(columns={'Survived':'SURVIVED'}, inplace=True)

# %%
data
# Out:
#      SURVIVED  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0   Third    0  22.0      1      0   7.2500        S
# 1           1   First    1  38.0      1      0  71.2833        C
# 2           1   Third    1  26.0      0      0   7.9250        S
# 3           1   First    1  35.0      1      0  53.1000        S
# 4           0   Third    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0  Second    0  27.0      0      0  13.0000        S
# 887         1   First    1  19.0      0      0  30.0000        S
# 888         0   Third    1   NaN      1      2  23.4500        S
# 889         1   First    0  26.0      0      0  30.0000        C
# 890         0   Third    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.rename(columns={'Age':' Age'}, inplace=True)

# %%
data.columns
# Out:
# Index(['SURVIVED', 'Pclass', 'Sex', ' Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
data[' Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name:  Age, Length: 891, dtype: float64

# %%
data.rename(columns={' Age':'Age'}, inplace=True)
data
# Out:
#      SURVIVED  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0   Third    0  22.0      1      0   7.2500        S
# 1           1   First    1  38.0      1      0  71.2833        C
# 2           1   Third    1  26.0      0      0   7.9250        S
# 3           1   First    1  35.0      1      0  53.1000        S
# 4           0   Third    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0  Second    0  27.0      0      0  13.0000        S
# 887         1   First    1  19.0      0      0  30.0000        S
# 888         0   Third    1   NaN      1      2  23.4500        S
# 889         1   First    0  26.0      0      0  30.0000        C
# 890         0   Third    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data
# Out:
#      SURVIVED  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0   Third    0  22.0      1      0   7.2500        S
# 1           1   First    1  38.0      1      0  71.2833        C
# 2           1   Third    1  26.0      0      0   7.9250        S
# 3           1   First    1  35.0      1      0  53.1000        S
# 4           0   Third    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0  Second    0  27.0      0      0  13.0000        S
# 887         1   First    1  19.0      0      0  30.0000        S
# 888         0   Third    1   NaN      1      2  23.4500        S
# 889         1   First    0  26.0      0      0  30.0000        C
# 890         0   Third    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# ### fillna

# %%
data.isnull().sum()
# Out:
# SURVIVED      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
Age_Mean = data.Age.mean()

# %%
Age_Mean
# Out:
# 29.69911764705882

# %%
data.Age.fillna(Age_Mean, inplace=True)

# %%
data.sample(20)
# Out:
#      SURVIVED  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 652         0   Third    0  21.000000      0      0   8.4333        S
# 707         1   First    0  42.000000      0      0  26.2875        S
# 420         0   Third    0  29.699118      0      0   7.8958        C
# 224         1   First    0  38.000000      1      0  90.0000        S
# 695         0  Second    0  52.000000      0      0  13.5000        S
# 106         1   Third    1  21.000000      0      0   7.6500        S
# 785         0   Third    0  25.000000      0      0   7.2500        S
# 612         1   Third    1  29.699118      1      0  15.5000        Q
# 694         0   First    0  60.000000      0      0  26.5500        S
# 848         0  Second    0  28.000000      0      1  33.0000        S
# 618         1  Second    1   4.000000      2      1  39.0000        S
# 100         0   Third    1  28.000000      0      0   7.8958        S
# 397         0  Second    0  46.000000      0      0  26.0000        S
# 167         0   Third    1  45.000000      1      4  27.9000        S
# 735         0   Third    0  28.500000      0      0  16.1000        S
# 84          1  Second    1  17.000000      0      0  10.5000        S
# 15          1  Second    1  55.000000      0      0  16.0000        S
# 387         1  Second    1  36.000000      0      0  13.0000        S
# 117         0  Second    0  29.000000      1      0  21.0000        S
# 549         1  Second    0   8.000000      1      1  36.7500        S

# %%
data.isnull().sum()
# Out:
# SURVIVED    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
data.Embarked.value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data.Embarked.fillna('S', inplace=True)

# %%
data.isnull().sum()
# Out:
# SURVIVED    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### pct_change

# %%
data
# Out:
#      SURVIVED  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0           0   Third    0  22.000000      1      0   7.2500        S
# 1           1   First    1  38.000000      1      0  71.2833        C
# 2           1   Third    1  26.000000      0      0   7.9250        S
# 3           1   First    1  35.000000      1      0  53.1000        S
# 4           0   Third    0  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0  Second    0  27.000000      0      0  13.0000        S
# 887         1   First    1  19.000000      0      0  30.0000        S
# 888         0   Third    1  29.699118      1      2  23.4500        S
# 889         1   First    0  26.000000      0      0  30.0000        C
# 890         0   Third    0  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
data.Fare.pct_change()
# Out:
# 0           NaN
# 1      8.832179
# 2     -0.888824
# 3      5.700315
# 4     -0.848399
#          ...
# 886   -0.553648
# 887    1.307692
# 888   -0.218333
# 889    0.279318
# 890   -0.741667
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# ### count

# %%
data.shape
# Out:
# (891, 8)

# %% [markdown]
# ### pd.cut

# %%
data
# Out:
#      SURVIVED  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0           0   Third    0  22.000000      1      0   7.2500        S
# 1           1   First    1  38.000000      1      0  71.2833        C
# 2           1   Third    1  26.000000      0      0   7.9250        S
# 3           1   First    1  35.000000      1      0  53.1000        S
# 4           0   Third    0  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0  Second    0  27.000000      0      0  13.0000        S
# 887         1   First    1  19.000000      0      0  30.0000        S
# 888         0   Third    1  29.699118      1      2  23.4500        S
# 889         1   First    0  26.000000      0      0  30.0000        C
# 890         0   Third    0  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
cutoff = [0, 18, 50, 85]
labels = ['Child', 'Adult', 'Old']
data['AGE_TYPE'] = pd.cut(data.Age, bins=cutoff, labels=labels)

# %%
data.sample(20)
# Out:
#      SURVIVED  Pclass  Sex        Age  SibSp  Parch      Fare Embarked  \
# 296         0   Third    0  23.500000      0      0    7.2292        C
# 739         0   Third    0  29.699118      0      0    7.8958        S
# 734         0  Second    0  23.000000      0      0   13.0000        S
# 831         1  Second    0   0.830000      1      1   18.7500        S
# 380         1   First    1  42.000000      0      0  227.5250        C
# 775         0   Third    0  18.000000      0      0    7.7500        S
# 565         0   Third    0  24.000000      2      0   24.1500        S
# 576         1  Second    1  34.000000      0      0   13.0000        S
# 15          1  Second    1  55.000000      0      0   16.0000        S
# 593         0   Third    1  29.699118      0      2    7.7500        Q
# 708         1   First    1  22.000000      0      0  151.5500        S
# 243         0   Third    0  22.000000      0      0    7.1250        S
# 119         0   Third    1   2.000000      4      2   31.2750        S
# 137         0   First    0  37.000000      1      0   53.1000        S
# 87          0   Third    0  29.699118      0      0    8.0500        S
# 23          1   First    0  28.000000      0      0   35.5000        S
# 385         0  Second    0  18.000000      0      0   73.5000        S
# 847         0   Third    0  35.000000      0      0    7.8958        C
# 117         0  Second    0  29.000000      1      0   21.0000        S
# 429         1   Third    0  32.000000      0      0    8.0500        S
#
#     AGE_TYPE
# 296    Adult
# 739    Adult
# 734    Adult
# 831    Child
# 380    Adult
# 775    Child
# 565    Adult
# 576    Adult
# 15       Old
# 593    Adult
# 708    Adult
# 243    Adult
# 119    Child
# 137    Adult
# 87     Adult
# 23     Adult
# 385    Child
# 847    Adult
# 117    Adult
# 429    Adult

# %% [markdown]
# # Class 13

# %% [markdown]
# ### n_largets and n-smallest

# %%
data.nlargest(5, 'Age')
# Out:
#      SURVIVED Pclass  Sex   Age  SibSp  Parch     Fare Embarked AGE_TYPE
# 630         1  First    0  80.0      0      0  30.0000        S      Old
# 851         0  Third    0  74.0      0      0   7.7750        S      Old
# 96          0  First    0  71.0      0      0  34.6542        C      Old
# 493         0  First    0  71.0      0      0  49.5042        C      Old
# 116         0  Third    0  70.5      0      0   7.7500        Q      Old

# %%
data.nlargest(10, 'Fare')
# Out:
#      SURVIVED Pclass  Sex   Age  SibSp  Parch      Fare Embarked AGE_TYPE
# 258         1  First    1  35.0      0      0  512.3292        C    Adult
# 679         1  First    0  36.0      0      1  512.3292        C    Adult
# 737         1  First    0  35.0      0      0  512.3292        C    Adult
# 27          0  First    0  19.0      3      2  263.0000        S    Adult
# 88          1  First    1  23.0      3      2  263.0000        S    Adult
# 341         1  First    1  24.0      3      2  263.0000        S    Adult
# 438         0  First    0  64.0      1      4  263.0000        S      Old
# 311         1  First    1  18.0      2      2  262.3750        C    Child
# 742         1  First    1  21.0      2      2  262.3750        C    Adult
# 118         0  First    0  24.0      0      1  247.5208        C    Adult

# %%
data.nsmallest(5, 'Age')
# Out:
#      SURVIVED  Pclass  Sex   Age  SibSp  Parch     Fare Embarked AGE_TYPE
# 803         1   Third    0  0.42      0      1   8.5167        C    Child
# 755         1  Second    0  0.67      1      1  14.5000        S    Child
# 469         1   Third    1  0.75      2      1  19.2583        C    Child
# 644         1   Third    1  0.75      2      1  19.2583        C    Child
# 78          1  Second    0  0.83      0      2  29.0000        S    Child

# %%
data.nsmallest(10, 'Fare')
# Out:
#      SURVIVED  Pclass  Sex        Age  SibSp  Parch  Fare Embarked AGE_TYPE
# 179         0   Third    0  36.000000      0      0   0.0        S    Adult
# 263         0   First    0  40.000000      0      0   0.0        S    Adult
# 271         1   Third    0  25.000000      0      0   0.0        S    Adult
# 277         0  Second    0  29.699118      0      0   0.0        S    Adult
# 302         0   Third    0  19.000000      0      0   0.0        S    Adult
# 413         0  Second    0  29.699118      0      0   0.0        S    Adult
# 466         0  Second    0  29.699118      0      0   0.0        S    Adult
# 481         0  Second    0  29.699118      0      0   0.0        S    Adult
# 597         0   Third    0  49.000000      0      0   0.0        S    Adult
# 633         0   First    0  29.699118      0      0   0.0        S    Adult

# %% [markdown]
# ### CROSS TABULATION
# * In statistics, a contingency table (also known as a cross tabulation or crosstab) is a type of table in a matrix format that displays the (multivariate) frequency distribution of the variables. They are heavily used in survey research, business intelligence, engineering, and scientific research. They provide a basic picture of the interrelation between two variables and can help find interactions between them. The term contingency table was first used by Karl Pearson in "On the Theory of Contingency and Its Relation to Association and Normal Correlation",[1] part of the Drapers' Company Research Memoirs Biometric Series I published in 1904.

# %%
pd.crosstab(data.Pclass, data.Embarked)
# Out:
# Embarked   C   Q    S
# Pclass
# First     85   2  129
# Second    17   3  164
# Third     66  72  353

# %%
pd.crosstab(data.Pclass, data.Embarked, margins=True)
# Out:
# Embarked    C   Q    S  All
# Pclass
# First      85   2  129  216
# Second     17   3  164  184
# Third      66  72  353  491
# All       168  77  646  891
